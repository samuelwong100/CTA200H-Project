# %% [markdown]
# Problem Statement: Match the APOGEE-red-clump catalog to Gaia DR2, integrate the orbits using galpy for 20 Gyr, and make a density plot in Galactocentric X and Y coordinates of all of the positions of the stars over the next 20 Gyr.

# %%
import astropy.units as u
import gaia_tools.load as gload
import gaia_tools.xmatch as gmatch
from galpy.potential import MWPotential2014
from galpy.orbit import Orbit
from astropy.coordinates import SkyCoord
import numpy as np
import time
import matplotlib.pyplot as plt

# %% [markdown]
# Load the data from APOGEE red clump and cross match with gaia2

# %%
aprc= gload.apogeerc()
# call the cross match cds function
gaia2_matches, matches_indx = gmatch.cds(aprc, xcat='vizier:I/345/gaia2')
# Out:
# C:\Users\user\AppData\Roaming\Python\Python36\site-packages\gaia_tools-0.2-py3.6.egg\gaia_tools\load\__init__.py:94: UserWarning: Falling back on simple APOGEE interface; for more functionality, install the jobovy/apogee package
#   warnings.warn("Falling back on simple APOGEE interface; for more functionality, install the jobovy/apogee package")

# %% [markdown]
# Since not all the stars have radial velocity, take out all the stars whose radial velocity is -9999.99 (an error value)

# %%
gaia2_matches = gaia2_matches[gaia2_matches['radial_velocity'] != -9999.99]
# store the number of stars to integrate
number_of_stars = np.size(gaia2_matches)
gaia2_matches
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7321b0a5cd0d> in <module>()
# ----> 1 gaia2_matches = gaia2_matches[gaia2_matches['radial_velocity'] != -9999.99]
#       2 # store the number of stars to integrate
#       3 number_of_stars = np.size(gaia2_matches)
#       4 gaia2_matches
#
# NameError: name 'gaia2_matches' is not defined

# %% [markdown]
# Get the list of the 6 position and vleocity coordinates for all of the stars

# %%
ra_list = gaia2_matches['ra']
dec_list = gaia2_matches['dec']
parallax_list = gaia2_matches['parallax']
vr_list = gaia2_matches['radial_velocity']
pm_ra_list = gaia2_matches['pmra']
pm_dec_list = gaia2_matches['pmdec']

# %% [markdown]
# Initialize variable needed for integrating orbit and storing the results

# %%
# create time array
ts = np.linspace(0,20,100)*u.Gyr
# initialize orbit list
o = []
# initialize star location plot
star_coord = []

# %% [markdown]
# Create an orbit object for each star

# %%
# %pylab inline

# initialize start time
start= time.time()

for i in range(np.size(gaia2_matches)):
    # for each star, get the 6 coordinates from list
    ra, dec, parallax, vr, v_ra, v_dec = ra_list[i], dec_list[i], parallax_list[i], vr_list[i], pm_ra_list[i], pm_dec_list[i]
    # use parallex to find radial distance
    d = 1/parallax # since parallax is given in milliarcsecond, its inverse is kpc
    
    # create orbit object
    # the units are already in desired form, radec = True means we are using righ ascention - declination initialization format
    o.append(Orbit(vxvv = [ra,dec,d,v_ra, v_dec,vr], radec = True)) 
    # for each star, integrate their orbit over the next 20 Gyr using the most up-to-date Milky Way potential
    o[i].integrate(ts,MWPotential2014)
    
    # store the x,y coordinate of each star after 20 Gyr
    coordinate = (o[i].x(20),o[i].y(20))
    star_coord.append(coordinate)
    
    # print out progess report and time taken
    if i%100 == 0:
        time_now = time.time() - start
        print(i/np.size(gaia2_matches), ", ", time_now)
    
    
# get the x,y coordinate into an array and save it
star_coord = np.array(star_coord)
x = star_coord[:, 0]
y = star_coord[:,1]
np.savez("x_y.npz", x = x, y = y)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# c:
# 0.5278973442702835 ,  39178.09197449684
# 0.5360188418744416 ,  39302.12106871605
# 0.5441403394785999 ,  39431.47046709061
# 0.5522618370827581 ,  39555.18254303932
# 0.5603833346869163 ,  39691.0893163681
# 0.5685048322910745 ,  39819.87668251991
# 0.5766263298952327 ,  39932.08010029793
# 0.5847478274993909 ,  40063.17459845543
# 0.5928693251035491 ,  40188.03074002266
# 0.6009908227077073 ,  40320.23330140114
# 0.6091123203118655 ,  40450.85277223587
# 0.6172338179160237 ,  40571.9006960392
# 0.625355315520182 ,  40690.26646590233
# 0.6334768131243401 ,  40811.303388834
# 0.6415983107284984 ,  40938.03563761711
# 0.6497198083326565 ,  41060.30663108826
# 0.6578413059368148 ,  41174.99219059944
# 0.6659628035409729 ,  41300.74938368797
# 0.6740843011451312 ,  41431.68087267876
# 0.6822057987492893 ,  41555.55479264259
# 0.6903272963534476 ,  41676.144689798355
# 0.6984487939576057 ,  41790.70924282074
# 0.706570291561764 ,  41897.00732254982
# 0.7146917891659222 ,  42009.53375864029
# 0.7228132867700804 ,  42127.98253369331
# 0.7309347843742386 ,  42252.01262760162
# 0.7390562819783968 ,  42368.163271188736
# 0.747177779582555 ,  42498.55072879791
# 0.7552992771867132 ,  42621.8177793026
# 0.7634207747908714 ,  42751.46019458771
# 0.7715422723950296 ,  42864.034633398056
# 0.7796637699991879 ,  42988.79676938057
# 0.7877852676033461 ,  43104.1413667202
# 0.7959067652075043 ,  43225.841327667236
# 0.8040282628116625 ,  43354.61069273949
# 0.8121497604158207 ,  43494.15867447853
# 0.8202712580199789 ,  43603.075904130936
# 0.8283927556241371 ,  43713.7642352581
# 0.8365142532282953 ,  43821.93342208862
# 0.8446357508324535 ,  43924.94531393051
# 0.8527572484366117 ,  44271.33155751228
# 0.86087874604077 ,  44371.740300655365
# 0.8690002436449281 ,  44472.62507104874
# 0.8771217412490864 ,  44582.6493639946
# 0.8852432388532445 ,  44699.515048503876
# 0.8933647364574028 ,  44806.97619485855
# 0.9014862340615609 ,  44919.81664896011
# 0.9096077316657192 ,  45026.09672784805
# 0.9177292292698773 ,  45127.27851510048
# 0.9258507268740356 ,  45232.43452954292
# 0.9339722244781937 ,  45338.46359419823
# 0.942093722082352 ,  45446.733786821365
# 0.9502152196865102 ,  45561.41834640503
# 0.9583367172906684 ,  45678.903066158295
# 0.9664582148948266 ,  45798.41390180588
# 0.9745797124989848 ,  45917.215696811676
# 0.982701210103143 ,  46035.20044517517
# 0.9908227077073012 ,  46150.887062072754
# 0.9989442053114594 ,  46271.962987184525

# %%
list_of_all_x  = np.empty((np.size(gaia2_matches),563))
list_of_all_y  = np.empty((np.size(gaia2_matches),563))
for i in range(np.size(gaia2_matches)):
    for j in range(563):
        list_of_all_x[i][j] = o[i].x(j)
        list_of_all_y[i][j] = o[i].y(j)
        print(i)

# %%
plt.scatter(x,y, s = 0.1)
plt.xlim(-15,15)
plt.ylim(-15,15)
plt.savefig("20 Gyr scatter plot.pdf")

# %%
data = np.load("x_y.npz")
nx=data['x']
ny=data['y']
# Out:
# [ True  True  True ...  True  True  True]
